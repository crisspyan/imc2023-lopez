# %% [markdown]
# <a href="https://colab.research.google.com/github/crisspyan/imc2023-lopez/blob/main/imc2023_Andrew_Lopez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import numpy as np
import matplotlib.pylab as plt
import librosa
import librosa.display

#import audio
# !git clone https://github.com/jcdevaney/imc2023.git
# Out:
# Cloning into 'imc2023'...
# remote: Enumerating objects: 66, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 66 (delta 25), reused 15 (delta 1), pack-reused 0
# Unpacking objects: 100% (66/66), 2.57 MiB | 2.73 MiB/s, done.

# %%
# open the audio file avm.wav with librosa.load()
file = 'imc2023/audioFiles/avm.wav'
samplingRate = 44100
sig, sr = librosa.load(file,mono=True,sr=samplingRate)

# %%
plt.plot(sig)

# %%
time=np.arange(0,sig.shape[0])/sr
plt.plot(time,sig)

# %%
# open the audio file avm.wav with librosa.load()
file = 'imc2023/audioFiles/avm.wav'
samplingRate = 441
sig, sr = librosa.load(file,mono=True,sr=samplingRate)

# %%
plt.plot(sig)

# %%
time=np.arange(0,sig.shape[0])/sr
plt.plot(time,sig)
